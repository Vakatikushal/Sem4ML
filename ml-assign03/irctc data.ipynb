# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_excel(r"Lab Session1 Data.xlsx" ,sheet_name="IRCTC Stock Price")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    249 non-null    object
#  1   Month   249 non-null    object
#  2   Day     249 non-null    object
#  3   Price   249 non-null    float64
#  4   Open    249 non-null    float64
#  5   High    249 non-null    float64
#  6   Low     249 non-null    float64
#  7   Volume  249 non-null    object
#  8   Chg%    249 non-null    float64
# dtypes: float64(5), object(4)
# memory usage: 17.6+ KB

# %%
df=data.loc[data['Day']=='Wed']

# %%
df
# Out:
#              Date Month  Day    Price     Open     High      Low   Volume  \
# 4    Jun 23, 2021   Jun  Wed  2078.25  2102.00  2111.40  2072.00  809.62K
# 9    Jun 16, 2021   Jun  Wed  2089.95  2109.45  2121.95  2075.30  856.94K
# 14   Jun 09, 2021   Jun  Wed  2071.20  2160.00  2163.00  2060.00    2.34M
# 19   Jun 02, 2021   Jun  Wed  1917.95  1899.95  1927.50  1895.25  576.76K
# 24   May 26, 2021   May  Wed  1894.05  1920.00  1930.05  1888.00  922.76K
# 29   May 19, 2021   May  Wed  1858.10  1844.00  1884.95  1840.00    2.10M
# 33   May 12, 2021   May  Wed  1746.60  1799.00  1829.00  1732.80    1.63M
# 38   May 05, 2021   May  Wed  1723.65  1775.00  1782.95  1715.00    1.22M
# 43   Apr 28, 2021   Apr  Wed  1795.85  1800.00  1818.00  1775.00    1.54M
# 56   Apr 07, 2021   Apr  Wed  1709.00  1684.20  1721.40  1673.00    1.47M
# 60   Mar 31, 2021   Mar  Wed  1757.00  1758.70  1774.95  1735.00    1.09M
# 64   Mar 24, 2021   Mar  Wed  1760.55  1829.70  1836.80  1750.40    2.09M
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 4 to 248
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    50 non-null     object
#  1   Month   50 non-null     object
#  2   Day     50 non-null     object
#  3   Price   50 non-null     float64
#  4   Open    50 non-null     float64
#  5   High    50 non-null     float64
#  6   Low     50 non-null     float64
#  7   Volume  50 non-null     object
#  8   Chg%    50 non-null     float64
# dtypes: float64(5), object(4)
# memory usage: 3.9+ KB

# %%
df['Price'].mean()
# Out:
# 1550.7060000000001

# %%
data['Price'].mean()
# Out:
# 1560.6634538152612

# %%
dm=data.loc[data['Month']=='Apr']

# %%
dm
# Out:
#             Date Month  Day    Price     Open     High      Low   Volume  \
# 41  Apr 30, 2021   Apr  Fri  1791.40  1784.90  1809.15  1757.75  756.66K
# 42  Apr 29, 2021   Apr  Thu  1792.55  1801.00  1818.00  1765.30    1.21M
# 43  Apr 28, 2021   Apr  Wed  1795.85  1800.00  1818.00  1775.00    1.54M
# 44  Apr 27, 2021   Apr  Tue  1793.20  1730.00  1802.60  1714.65    2.26M
# 45  Apr 26, 2021   Apr  Mon  1730.85  1721.90  1739.25  1718.00  791.76K
# 46  Apr 23, 2021   Apr  Fri  1712.00  1670.00  1717.90  1661.00    1.63M
# 47  Apr 22, 2021   Apr  Thu  1673.05  1614.00  1681.00  1614.00  988.50K
# 48  Apr 20, 2021   Apr  Tue  1640.05  1616.00  1648.95  1616.00    1.14M
# 49  Apr 19, 2021   Apr  Mon  1612.70  1550.00  1620.00  1550.00    1.19M
# 50  Apr 16, 2021   Apr  Fri  1627.45  1611.00  1638.10  1606.00  968.08K
# 51  Apr 15, 2021   Apr  Thu  1608.10  1592.10  1632.90  1589.00    1.16M
# 52  Apr 13, 2021   Apr  Tue  1611.65  1582.05  1623.00  1582.05    1.23M
# ...

# %%
dm['Price'].mean()
# Out:
# 1698.9526315789474

# %%
neg_count=data['Chg%'].apply(lambda x: 1 if x < 0 else 0)

# %%
np.unique(neg_count,return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([125, 124], dtype=int64))

# %%
profit_wednesdasy_count=df['Chg%'].apply(lambda x: 1 if x > 0 else 0)

# %%
np.unique(profit_wednesdasy_count,return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([29, 21], dtype=int64))

# %%
profit = lambda x:x>0
profit_count = (data.loc[data['Day']=='Wed', 'Chg%'] > 0).sum()
total=len(data)
probablity_wed = profit_count/total

print(f"the probability of making profit in the stock on wednesday is {probablity_wed}")

profit_wednesday = df[df['Chg%'] > 0]
num_profit_wednesdays = len(profit_wednesday)
total_wed = len(df)
conditional_prob_wed = num_profit_wednesdays/total_wed
print(f"The cnditional probablity of making profit, given that today is wednesday = {conditional_prob_wed}")
# Out:
# the probability of making profit in the stock on wednesday is 0.08433734939759036
# The cnditional probablity of making profit, given that today is wednesday = 0.42

# %%
loss = lambda x:x<0 
loss_count = (df['Chg%'] <0).sum()
total = len(df)
probablity = loss_count/total

print(f"the probability of making loss in the stock is {probablity}")
# Out:
# the probability of making loss in the stock is 0.58

# %%
plt.scatter(data['Day'],data['Chg%'])
